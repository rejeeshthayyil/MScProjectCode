# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
# %config InlineBackend.figure_format = 'retina'
# %config Completer.use_jedi = False # this to force autocompletion 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\rejee\anaconda3\lib\site-packages (2.11.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.2.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.44.0)
# Requirement already satisfied: setuptools in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (58.0.4)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (13.0.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.4.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: packaging in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (21.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.12.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.24.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.20.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\rejee\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.37.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.26.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\rejee\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\rejee\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.6.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\rejee\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\rejee\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\rejee\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\rejee\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\rejee\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\rejee\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\rejee\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\rejee\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\rejee\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\rejee\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\rejee\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rejee\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rejee\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2022.9.24)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\rejee\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\rejee\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.11.0->tensorflow) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf

# %%
from copyreg import pickle
from nltk.corpus import wordnet as wn
from nltk.tokenize import word_tokenize
from nltk.inference.prover9 import nltk
from nltk.stem import WordNetLemmatizer
from tqdm import tqdm
import numpy as np
import pandas as pd
import tensorflow as tf
from keras_preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import one_hot
from sklearn.model_selection import train_test_split
from keras.models import Model
from sklearn import metrics
import matplotlib as plt
import os
from tensorflow.keras.optimizers import RMSprop
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from keras.callbacks import EarlyStopping
from keras.layers import LSTM, Activation, Dense, Dropout
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
import nltk
import re
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.corpus import words
nltk.download('words')
stopwords = stopwords.words('english')
nltk.download('stopwords')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\rejee\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rejee\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\rejee\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\rejee\anaconda3\lib\site-packages (2.11.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.3.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (13.0.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.12.1)
# Requirement already satisfied: packaging in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (21.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.20.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.24.0)
# Requirement already satisfied: setuptools in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (58.0.4)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.4.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.44.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.2.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\rejee\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.37.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.26.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\rejee\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\rejee\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\rejee\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\rejee\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.6.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\rejee\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\rejee\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\rejee\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\rejee\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\rejee\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\rejee\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\rejee\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\rejee\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\rejee\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rejee\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\rejee\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rejee\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2022.9.24)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\rejee\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\rejee\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.11.0->tensorflow) (3.0.4)

# %%
import nltk
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rejee\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\rejee\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\rejee\anaconda3\lib\site-packages (1.8.2.2)
# Requirement already satisfied: pillow in c:\users\rejee\anaconda3\lib\site-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\rejee\anaconda3\lib\site-packages (from wordcloud) (1.20.3)
# Requirement already satisfied: matplotlib in c:\users\rejee\anaconda3\lib\site-packages (from wordcloud) (3.4.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rejee\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\rejee\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\rejee\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rejee\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: six in c:\users\rejee\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.16.0)

# %%
from tqdm.notebook import tqdm_notebook
tqdm_notebook.pandas()

# %%
import string 
from wordcloud import wordcloud

# %%
df=pd.read_csv(r'C:\Users\rejee\Desktop\Agitation.csv')

# %%
df
# Out:
#      Location  level        Observation Behaviour
# 0     Kitchen      5          Withdrawn    Normal
# 1     Kitchen      3  Vocal1, Withdrawn    Normal
# 2       Other      3          Withdrawn    Normal
# 3       Other      4          Withdrawn    Normal
# 4       Other      4  Vocal2, Withdrawn    Normal
# ...       ...    ...                ...       ...
# 4987  Kitchen      1        Repetition;    Normal
# 4988  Kitchen      1        Repetition;    Normal
# 4989  Kitchen      1        Repetition;    Normal
# 4990  Kitchen      1        Repetition;    Normal
# 4991  Kitchen      1        Repetition;    Normal
#
# [4992 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4992 entries, 0 to 4991
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Location     4992 non-null   object
#  1   level        4992 non-null   int64
#  2   Observation  4992 non-null   object
#  3   Behaviour    4992 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 156.1+ KB

# %%
print(df.shape)
print(df.isnull().values.any())
#df.dropna(axis=0, inplace=true)
print(df.shape)
# Out:
# (4992, 4)
# False
# (4992, 4)

# %%
df.describe()
# Out:
#              level
# count  4992.000000
# mean      3.868590
# std       2.934187
# min       1.000000
# 25%       1.000000
# 50%       3.000000
# 75%       7.000000
# max       9.000000

# %%
df['Behaviour'] = df.Behaviour.map({'Normal':0, 'Agitation':1})
df.head()
# Out:
#   Location  level        Observation  Behaviour
# 0  Kitchen      5          Withdrawn          0
# 1  Kitchen      3  Vocal1, Withdrawn          0
# 2    Other      3          Withdrawn          0
# 3    Other      4          Withdrawn          0
# 4    Other      4  Vocal2, Withdrawn          0

# %%
sns.set()
sns.countplot(df.Behaviour)
plt.show()

# %%
df['word_length'] = df['Observation'].apply(lambda x:len(x.split()))

# %%
df.head()
# Out:
#   Location  level        Observation  Behaviour  word_length
# 0  Kitchen      5          Withdrawn          0            1
# 1  Kitchen      3  Vocal1, Withdrawn          0            2
# 2    Other      3          Withdrawn          0            1
# 3    Other      4          Withdrawn          0            1
# 4    Other      4  Vocal2, Withdrawn          0            2

# %%
plt.figure(figsize=(8,8))
ax=sns.countplot(x=df["level"],data=df,order=df["level"].value_counts().index)
for p, label in zip(ax.patches, df["level"].value_counts()):
    ax.annotate(label,(p.get_x()+0.25,p.get_height()+0.5))

# %%
df_observation=df.groupby('level').filter(lambda x: len(x)>=10)
df.observatioin_group=df_observation.groupby('level')

# %%
print(len(df_observation))
print(len(df.observatioin_group))
# Out:
# 4992
# 9

# %%
plt.figure(figsize=(8,8))
sns.countplot(y="Location",hue="level",data=df_observation)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Location'>

# %%
df.groupby("Location").count()
# Out:
#              level  Observation  Behaviour  word_length
# Location
# Bedroom        368          368        368          368
# Dining Room     64           64         64           64
# Entryway        80           80         80           80
# Kitchen       4032         4032       4032         4032
# Living Room    192          192        192          192
# Other          256          256        256          256

# %%
df_location=df.groupby("Location").filter(lambda x: len(x)>=4)
df_locationGroup=df_location.groupby("Location")
print(len(df_locationGroup))
# Out:
# 6

# %%
plt.figure(figsize=(10,10))
sns.countplot(y="Location",hue="level",data=df_location)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Location'>

# %%
df['word_length'] = df['Observation'].apply(lambda x:len(x.split()))
df.head(10)
# Out:
#   Location  level                       Observation  Behaviour  word_length
# 0  Kitchen      5                         Withdrawn          0            1
# 1  Kitchen      3                 Vocal1, Withdrawn          0            2
# 2    Other      3                         Withdrawn          0            1
# 3    Other      4                         Withdrawn          0            1
# 4    Other      4                 Vocal2, Withdrawn          0            2
# 5  Kitchen      3                         Withdrawn          0            1
# 6  Bedroom      4  Communication, Vocal1, Withdrawn          0            3
# 7  Bedroom      3                          Vocal1,0          0            1
# 8    Other      9                   Vocal1; Vocal2;          1            2
# 9    Other      7       Repetition; Vocal1; Vocal2;          0            3

# %%
plt.figure(figsize=(8, 8))

df[df.Behaviour==0].word_length.plot(bins=35, kind='hist', color='blue', 
                                       label='Normal', alpha=0.6)
df[df.Behaviour == 1].word_length.plot(kind='hist', color='red', 
                                       label='Agitation', alpha=0.6)
plt.legend()
plt.xlabel("message Length")
plt.show()

# %%
df.groupby('Behaviour').mean()
# Out:
#               level  word_length
# Behaviour
# 0          2.926641     1.911197
# 1          8.471698     3.037736

# %%
df[df.Behaviour == 0].describe()
# Out:
#              level  Behaviour  word_length
# count  4144.000000     4144.0  4144.000000
# mean      2.926641        0.0     1.911197
# std       2.257484        0.0     1.190448
# min       1.000000        0.0     1.000000
# 25%       1.000000        0.0     1.000000
# 50%       2.000000        0.0     1.000000
# 75%       5.000000        0.0     3.000000
# max       8.000000        0.0     7.000000

# %%
lemmatizer = WordNetLemmatizer()

# %%
for index, row in df.iterrows():
    filter_sentence = []
    sentence = row['Observation']
    sentence = re.sub(r'[^\w\s]', '', sentence)  # re move punctuations
    sentence = re.sub(r"[^a-zA-Z0-9]", " ", sentence.lower())
    words = nltk.word_tokenize(sentence)
    words = [w for w in words if not w in stopwords]
    for word in words:
        filter_sentence.append(lemmatizer.lemmatize(word))
    print(filter_sentence)
    df.at[index, 'Observation'] = filter_sentence
# Out:
# ['withdrawn']
# ['vocal1', 'withdrawn']
# ['withdrawn']
# ['withdrawn']
# ['vocal2', 'withdrawn']
# ['withdrawn']
# ['communication', 'vocal1', 'withdrawn']
# ['vocal10']
# ['vocal1', 'vocal2']
# ['repetition', 'vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal2']
# ['vocal1']
# ['vocal1', 'vocal2']
# ['repetition', 'vocal1', 'vocal2']
# ['withdrawn']
# ['repetition', 'vocal1', 'vocal2']
# ['vocal1']
# ['clothing', 'communication', 'vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['frustration', 'vocal1']
# ['vocal1', 'vocal2']
# ['communication', 'vocal1']
# ['vocal1', 'vocal2']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'vocal1', 'vocal2']
# ['repetition']
# ['repetition']
# ['communication']
# ['repetition']
# ['frustration']
# ['withdrawn']
# ['frustration', 'withdrawn']
# ['repetition']
# ['frustration', 'withdrawn']
# ['frustration', 'withdrawn']
# ['repetition']
# ['repetition']
# ['withdrawn']
# ['repetition']
# ['repetition']
# ['frustration']
# ['repetition']
# ['ambulation', 'frustration']
# ['communication']
# ['communication', 'repetition']
# ['repetition']
# ['repetition']
# ['frustration', 'withdrawn']
# ['lost']
# ['ambulation', 'frustration', 'withdrawn']
# ['frustration']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['frustration', 'withdrawn']
# ['repetition']
# ['repetition']
# ['repetition']
# ['frustration']
# ['repetition']
# ['lost']
# ['frustration', 'lost']
# ['frustration', 'lost', 'withdrawn']
# ['frustration', 'withdrawn']
# ['frustration', 'repetition']
# ['ambulation', 'frustration', 'repetition']
# ['ambulation', 'frustration']
# ['repetition']
# ['repetition']
# ['frustration', 'repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['frustration', 'withdrawn']
# ['lost']
# ['vocal2', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['repetition', 'vocal1', 'withdrawn']
# ['vocal2', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['withdrawn']
# ['clothing', 'frustration', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['vocal1', 'vocal2']
# ['ambulation', 'communication', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'communication', 'frustration', 'touching', 'withdrawn']
# ['ambulation', 'clothing', 'frustration', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'vocal1', 'withdrawn']
# ['clothing', 'lost', 'vocal1']
# ['frustration', 'withdrawn']
# ['clothing', 'frustration', 'vocal1', 'withdrawn']
# ['clothing', 'frustration', 'touching']
# ['communication', 'touching']
# ['ambulation', 'clothing', 'frustration', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'clothing', 'frustration', 'repetition', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'clothing', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['vocal2']
# ['frustration', 'repetition', 'vocal1', 'vocal2']
# ['clothing', 'frustration', 'touching']
# ['vocal2']
# ['vocal1', 'withdrawn']
# ['vocal1']
# ['repetition', 'vocal1', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['vocal1', 'withdrawn']
# ['lostrepetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['clothing']
# ['repetition']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication']
# ['communication', 'repetition']
# ['communication', 'repetition']
# ['repetition']
# ['communication', 'withdrawn']
# ['lost', 'repetition', 'touching', 'vocal1', 'withdrawn']
# ['repetition']
# ['oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['lost', 'repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['repetition']
# ['repetitionvocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['lost']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'frustration', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition']
# ['lostrepetition', 'vocal1']
# ['frustration', 'repetition', 'vocal1']
# ['repetition']
# ['lost', 'repetition', 'vocal1']
# ['lost', 'repetition', 'vocal1']
# ['repetition']
# ['frustration', 'repetition', 'vocal1']
# ['repetition']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['lostrepetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition']
# ['communication', 'repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication', 'lost']
# ['lost']
# ['lost']
# ['communication', 'lost']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'lost', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'vocal1']
# ['communication']
# ['communication']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'physical2', 'shadowing']
# ['repetition']
# ['vocal1']
# ['frustration']
# ['vocal1']
# ['withdrawn']
# ['repetition']
# ['frustration']
# ['withdrawn']
# ['communication', 'frustration']
# ['vocal1']
# ['ambulation', 'vocal1']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication']
# ['repetition']
# ['repetition']
# ['vocal2']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication', 'vocal1', 'vocal2']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['withdrawn']
# ['vocal1', 'withdrawn']
# ['withdrawn']
# ['withdrawn']
# ['vocal2', 'withdrawn']
# ['withdrawn']
# ['communication', 'vocal1', 'withdrawn']
# ['vocal10']
# ['vocal1', 'vocal2']
# ['repetition', 'vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal2']
# ['vocal1']
# ['vocal1', 'vocal2']
# ['repetition', 'vocal1', 'vocal2']
# ['withdrawn']
# ['repetition', 'vocal1', 'vocal2']
# ['vocal1']
# ['clothing', 'communication', 'vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['frustration', 'vocal1']
# ['vocal1', 'vocal2']
# ['communication', 'vocal1']
# ['vocal1', 'vocal2']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'vocal1', 'vocal2']
# ['repetition']
# ['repetition']
# ['communication']
# ['repetition']
# ['frustration']
# ['withdrawn']
# ['frustration', 'withdrawn']
# ['repetition']
# ['frustration', 'withdrawn']
# ['frustration', 'withdrawn']
# ['repetition']
# ['repetition']
# ['withdrawn']
# ['repetition']
# ['repetition']
# ['frustration']
# ['repetition']
# ['ambulation', 'frustration']
# ['communication']
# ['communication', 'repetition']
# ['repetition']
# ['repetition']
# ['frustration', 'withdrawn']
# ['lost']
# ['ambulation', 'frustration', 'withdrawn']
# ['frustration']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['frustration', 'withdrawn']
# ['repetition']
# ['repetition']
# ['repetition']
# ['frustration']
# ['repetition']
# ['lost']
# ['frustration', 'lost']
# ['frustration', 'lost', 'withdrawn']
# ['frustration', 'withdrawn']
# ['frustration', 'repetition']
# ['ambulation', 'frustration', 'repetition']
# ['ambulation', 'frustration']
# ['repetition']
# ['repetition']
# ['frustration', 'repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['frustration', 'withdrawn']
# ['lost']
# ['vocal2', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['repetition', 'vocal1', 'withdrawn']
# ['vocal2', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['withdrawn']
# ['clothing', 'frustration', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['vocal1', 'vocal2']
# ['ambulation', 'communication', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'communication', 'frustration', 'touching', 'withdrawn']
# ['ambulation', 'clothing', 'frustration', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'vocal1', 'withdrawn']
# ['clothing', 'lost', 'vocal1']
# ['frustration', 'withdrawn']
# ['clothing', 'frustration', 'vocal1', 'withdrawn']
# ['clothing', 'frustration', 'touching']
# ['communication', 'touching']
# ['ambulation', 'clothing', 'frustration', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'clothing', 'frustration', 'repetition', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'clothing', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['vocal2']
# ['frustration', 'repetition', 'vocal1', 'vocal2']
# ['clothing', 'frustration', 'touching']
# ['vocal2']
# ['vocal1', 'withdrawn']
# ['vocal1']
# ['repetition', 'vocal1', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['vocal1', 'withdrawn']
# ['lostrepetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['clothing']
# ['repetition']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication']
# ['communication', 'repetition']
# ['communication', 'repetition']
# ['repetition']
# ['communication', 'withdrawn']
# ['lost', 'repetition', 'touching', 'vocal1', 'withdrawn']
# ['repetition']
# ['oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['lost', 'repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['repetition']
# ['repetitionvocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['lost']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'frustration', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition']
# ['lostrepetition', 'vocal1']
# ['frustration', 'repetition', 'vocal1']
# ['repetition']
# ['lost', 'repetition', 'vocal1']
# ['lost', 'repetition', 'vocal1']
# ['repetition']
# ['frustration', 'repetition', 'vocal1']
# ['repetition']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['lostrepetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition']
# ['communication', 'repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication', 'lost']
# ['lost']
# ['lost']
# ['communication', 'lost']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'lost', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'vocal1']
# ['communication']
# ['communication']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'physical2', 'shadowing']
# ['repetition']
# ['vocal1']
# ['frustration']
# ['vocal1']
# ['withdrawn']
# ['repetition']
# ['frustration']
# ['withdrawn']
# ['communication', 'frustration']
# ['vocal1']
# ['ambulation', 'vocal1']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication']
# ['repetition']
# ['repetition']
# ['vocal2']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication', 'vocal1', 'vocal2']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['withdrawn']
# ['vocal1', 'withdrawn']
# ['withdrawn']
# ['withdrawn']
# ['vocal2', 'withdrawn']
# ['withdrawn']
# ['communication', 'vocal1', 'withdrawn']
# ['vocal10']
# ['vocal1', 'vocal2']
# ['repetition', 'vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal2']
# ['vocal1']
# ['vocal1', 'vocal2']
# ['repetition', 'vocal1', 'vocal2']
# ['withdrawn']
# ['repetition', 'vocal1', 'vocal2']
# ['vocal1']
# ['clothing', 'communication', 'vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['frustration', 'vocal1']
# ['vocal1', 'vocal2']
# ['communication', 'vocal1']
# ['vocal1', 'vocal2']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'vocal1', 'vocal2']
# ['repetition']
# ['repetition']
# ['communication']
# ['repetition']
# ['frustration']
# ['withdrawn']
# ['frustration', 'withdrawn']
# ['repetition']
# ['frustration', 'withdrawn']
# ['frustration', 'withdrawn']
# ['repetition']
# ['repetition']
# ['withdrawn']
# ['repetition']
# ['repetition']
# ['frustration']
# ['repetition']
# ['ambulation', 'frustration']
# ['communication']
# ['communication', 'repetition']
# ['repetition']
# ['repetition']
# ['frustration', 'withdrawn']
# ['lost']
# ['ambulation', 'frustration', 'withdrawn']
# ['frustration']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['frustration', 'withdrawn']
# ['repetition']
# ['repetition']
# ['repetition']
# ['frustration']
# ['repetition']
# ['lost']
# ['frustration', 'lost']
# ['frustration', 'lost', 'withdrawn']
# ['frustration', 'withdrawn']
# ['frustration', 'repetition']
# ['ambulation', 'frustration', 'repetition']
# ['ambulation', 'frustration']
# ['repetition']
# ['repetition']
# ['frustration', 'repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['frustration', 'withdrawn']
# ['lost']
# ['vocal2', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['repetition', 'vocal1', 'withdrawn']
# ['vocal2', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['withdrawn']
# ['clothing', 'frustration', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['vocal1', 'vocal2']
# ['ambulation', 'communication', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'communication', 'frustration', 'touching', 'withdrawn']
# ['ambulation', 'clothing', 'frustration', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'vocal1', 'withdrawn']
# ['clothing', 'lost', 'vocal1']
# ['frustration', 'withdrawn']
# ['clothing', 'frustration', 'vocal1', 'withdrawn']
# ['clothing', 'frustration', 'touching']
# ['communication', 'touching']
# ['ambulation', 'clothing', 'frustration', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'clothing', 'frustration', 'repetition', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'clothing', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['vocal2']
# ['frustration', 'repetition', 'vocal1', 'vocal2']
# ['clothing', 'frustration', 'touching']
# ['vocal2']
# ['vocal1', 'withdrawn']
# ['vocal1']
# ['repetition', 'vocal1', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['vocal1', 'withdrawn']
# ['lostrepetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['clothing']
# ['repetition']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication']
# ['communication', 'repetition']
# ['communication', 'repetition']
# ['repetition']
# ['communication', 'withdrawn']
# ['lost', 'repetition', 'touching', 'vocal1', 'withdrawn']
# ['repetition']
# ['oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['lost', 'repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['repetition']
# ['repetitionvocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['lost']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'frustration', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition']
# ['lostrepetition', 'vocal1']
# ['frustration', 'repetition', 'vocal1']
# ['repetition']
# ['lost', 'repetition', 'vocal1']
# ['lost', 'repetition', 'vocal1']
# ['repetition']
# ['frustration', 'repetition', 'vocal1']
# ['repetition']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['lostrepetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition']
# ['communication', 'repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication', 'lost']
# ['lost']
# ['lost']
# ['communication', 'lost']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'lost', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'vocal1']
# ['communication']
# ['communication']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'physical2', 'shadowing']
# ['repetition']
# ['vocal1']
# ['frustration']
# ['vocal1']
# ['withdrawn']
# ['repetition']
# ['frustration']
# ['withdrawn']
# ['communication', 'frustration']
# ['vocal1']
# ['ambulation', 'vocal1']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication']
# ['repetition']
# ['repetition']
# ['vocal2']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication', 'vocal1', 'vocal2']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['withdrawn']
# ['vocal1', 'withdrawn']
# ['withdrawn']
# ['withdrawn']
# ['vocal2', 'withdrawn']
# ['withdrawn']
# ['communication', 'vocal1', 'withdrawn']
# ['vocal10']
# ['vocal1', 'vocal2']
# ['repetition', 'vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal2']
# ['vocal1']
# ['vocal1', 'vocal2']
# ['repetition', 'vocal1', 'vocal2']
# ['withdrawn']
# ['repetition', 'vocal1', 'vocal2']
# ['vocal1']
# ['clothing', 'communication', 'vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['frustration', 'vocal1']
# ['vocal1', 'vocal2']
# ['communication', 'vocal1']
# ['vocal1', 'vocal2']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'vocal1', 'vocal2']
# ['repetition']
# ['repetition']
# ['communication']
# ['repetition']
# ['frustration']
# ['withdrawn']
# ['frustration', 'withdrawn']
# ['repetition']
# ['frustration', 'withdrawn']
# ['frustration', 'withdrawn']
# ['repetition']
# ['repetition']
# ['withdrawn']
# ['repetition']
# ['repetition']
# ['frustration']
# ['repetition']
# ['ambulation', 'frustration']
# ['communication']
# ['communication', 'repetition']
# ['repetition']
# ['repetition']
# ['frustration', 'withdrawn']
# ['lost']
# ['ambulation', 'frustration', 'withdrawn']
# ['frustration']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['frustration', 'withdrawn']
# ['repetition']
# ['repetition']
# ['repetition']
# ['frustration']
# ['repetition']
# ['lost']
# ['frustration', 'lost']
# ['frustration', 'lost', 'withdrawn']
# ['frustration', 'withdrawn']
# ['frustration', 'repetition']
# ['ambulation', 'frustration', 'repetition']
# ['ambulation', 'frustration']
# ['repetition']
# ['repetition']
# ['frustration', 'repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['frustration', 'withdrawn']
# ['lost']
# ['vocal2', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['repetition', 'vocal1', 'withdrawn']
# ['vocal2', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['withdrawn']
# ['clothing', 'frustration', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['vocal1', 'vocal2']
# ['ambulation', 'communication', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'communication', 'frustration', 'touching', 'withdrawn']
# ['ambulation', 'clothing', 'frustration', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'vocal1', 'withdrawn']
# ['clothing', 'lost', 'vocal1']
# ['frustration', 'withdrawn']
# ['clothing', 'frustration', 'vocal1', 'withdrawn']
# ['clothing', 'frustration', 'touching']
# ['communication', 'touching']
# ['ambulation', 'clothing', 'frustration', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'clothing', 'frustration', 'repetition', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'clothing', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['vocal2']
# ['frustration', 'repetition', 'vocal1', 'vocal2']
# ['clothing', 'frustration', 'touching']
# ['vocal2']
# ['vocal1', 'withdrawn']
# ['vocal1']
# ['repetition', 'vocal1', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['vocal1', 'withdrawn']
# ['lostrepetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['clothing']
# ['repetition']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication']
# ['communication', 'repetition']
# ['communication', 'repetition']
# ['repetition']
# ['communication', 'withdrawn']
# ['lost', 'repetition', 'touching', 'vocal1', 'withdrawn']
# ['repetition']
# ['oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['lost', 'repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['repetition']
# ['repetitionvocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['lost']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'frustration', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition']
# ['lostrepetition', 'vocal1']
# ['frustration', 'repetition', 'vocal1']
# ['repetition']
# ['lost', 'repetition', 'vocal1']
# ['lost', 'repetition', 'vocal1']
# ['repetition']
# ['frustration', 'repetition', 'vocal1']
# ['repetition']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['lostrepetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition']
# ['communication', 'repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication', 'lost']
# ['lost']
# ['lost']
# ['communication', 'lost']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'lost', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'vocal1']
# ['communication']
# ['communication']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'physical2', 'shadowing']
# ['repetition']
# ['vocal1']
# ['frustration']
# ['vocal1']
# ['withdrawn']
# ['repetition']
# ['frustration']
# ['withdrawn']
# ['communication', 'frustration']
# ['vocal1']
# ['ambulation', 'vocal1']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication']
# ['repetition']
# ['repetition']
# ['vocal2']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication', 'vocal1', 'vocal2']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['withdrawn']
# ['vocal1', 'withdrawn']
# ['withdrawn']
# ['withdrawn']
# ['vocal2', 'withdrawn']
# ['withdrawn']
# ['communication', 'vocal1', 'withdrawn']
# ['vocal10']
# ['vocal1', 'vocal2']
# ['repetition', 'vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal2']
# ['vocal1']
# ['vocal1', 'vocal2']
# ['repetition', 'vocal1', 'vocal2']
# ['withdrawn']
# ['repetition', 'vocal1', 'vocal2']
# ['vocal1']
# ['clothing', 'communication', 'vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['frustration', 'vocal1']
# ['vocal1', 'vocal2']
# ['communication', 'vocal1']
# ['vocal1', 'vocal2']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'vocal1', 'vocal2']
# ['repetition']
# ['repetition']
# ['communication']
# ['repetition']
# ['frustration']
# ['withdrawn']
# ['frustration', 'withdrawn']
# ['repetition']
# ['frustration', 'withdrawn']
# ['frustration', 'withdrawn']
# ['repetition']
# ['repetition']
# ['withdrawn']
# ['repetition']
# ['repetition']
# ['frustration']
# ['repetition']
# ['ambulation', 'frustration']
# ['communication']
# ['communication', 'repetition']
# ['repetition']
# ['repetition']
# ['frustration', 'withdrawn']
# ['lost']
# ['ambulation', 'frustration', 'withdrawn']
# ['frustration']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['frustration', 'withdrawn']
# ['repetition']
# ['repetition']
# ['repetition']
# ['frustration']
# ['repetition']
# ['lost']
# ['frustration', 'lost']
# ['frustration', 'lost', 'withdrawn']
# ['frustration', 'withdrawn']
# ['frustration', 'repetition']
# ['ambulation', 'frustration', 'repetition']
# ['ambulation', 'frustration']
# ['repetition']
# ['repetition']
# ['frustration', 'repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['frustration', 'withdrawn']
# ['lost']
# ['vocal2', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['repetition', 'vocal1', 'withdrawn']
# ['vocal2', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['withdrawn']
# ['clothing', 'frustration', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['vocal1', 'vocal2']
# ['ambulation', 'communication', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'communication', 'frustration', 'touching', 'withdrawn']
# ['ambulation', 'clothing', 'frustration', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'vocal1', 'withdrawn']
# ['clothing', 'lost', 'vocal1']
# ['frustration', 'withdrawn']
# ['clothing', 'frustration', 'vocal1', 'withdrawn']
# ['clothing', 'frustration', 'touching']
# ['communication', 'touching']
# ['ambulation', 'clothing', 'frustration', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'clothing', 'frustration', 'repetition', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'clothing', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['vocal2']
# ['frustration', 'repetition', 'vocal1', 'vocal2']
# ['clothing', 'frustration', 'touching']
# ['vocal2']
# ['vocal1', 'withdrawn']
# ['vocal1']
# ['repetition', 'vocal1', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['vocal1', 'withdrawn']
# ['lostrepetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['clothing']
# ['repetition']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication']
# ['communication', 'repetition']
# ['communication', 'repetition']
# ['repetition']
# ['communication', 'withdrawn']
# ['lost', 'repetition', 'touching', 'vocal1', 'withdrawn']
# ['repetition']
# ['oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['lost', 'repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['repetition']
# ['repetitionvocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['lost']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'frustration', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition']
# ['lostrepetition', 'vocal1']
# ['frustration', 'repetition', 'vocal1']
# ['repetition']
# ['lost', 'repetition', 'vocal1']
# ['lost', 'repetition', 'vocal1']
# ['repetition']
# ['frustration', 'repetition', 'vocal1']
# ['repetition']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['lostrepetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition']
# ['communication', 'repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication', 'lost']
# ['lost']
# ['lost']
# ['communication', 'lost']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'lost', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'vocal1']
# ['communication']
# ['communication']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'physical2', 'shadowing']
# ['repetition']
# ['vocal1']
# ['frustration']
# ['vocal1']
# ['withdrawn']
# ['repetition']
# ['frustration']
# ['withdrawn']
# ['communication', 'frustration']
# ['vocal1']
# ['ambulation', 'vocal1']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication']
# ['repetition']
# ['repetition']
# ['vocal2']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication', 'vocal1', 'vocal2']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['withdrawn']
# ['vocal1', 'withdrawn']
# ['withdrawn']
# ['withdrawn']
# ['vocal2', 'withdrawn']
# ['withdrawn']
# ['communication', 'vocal1', 'withdrawn']
# ['vocal10']
# ['vocal1', 'vocal2']
# ['repetition', 'vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal2']
# ['vocal1']
# ['vocal1', 'vocal2']
# ['repetition', 'vocal1', 'vocal2']
# ['withdrawn']
# ['repetition', 'vocal1', 'vocal2']
# ['vocal1']
# ['clothing', 'communication', 'vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['frustration', 'vocal1']
# ['vocal1', 'vocal2']
# ['communication', 'vocal1']
# ['vocal1', 'vocal2']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'vocal1', 'vocal2']
# ['repetition']
# ['repetition']
# ['communication']
# ['repetition']
# ['frustration']
# ['withdrawn']
# ['frustration', 'withdrawn']
# ['repetition']
# ['frustration', 'withdrawn']
# ['frustration', 'withdrawn']
# ['repetition']
# ['repetition']
# ['withdrawn']
# ['repetition']
# ['repetition']
# ['frustration']
# ['repetition']
# ['ambulation', 'frustration']
# ['communication']
# ['communication', 'repetition']
# ['repetition']
# ['repetition']
# ['frustration', 'withdrawn']
# ['lost']
# ['ambulation', 'frustration', 'withdrawn']
# ['frustration']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['frustration', 'withdrawn']
# ['repetition']
# ['repetition']
# ['repetition']
# ['frustration']
# ['repetition']
# ['lost']
# ['frustration', 'lost']
# ['frustration', 'lost', 'withdrawn']
# ['frustration', 'withdrawn']
# ['frustration', 'repetition']
# ['ambulation', 'frustration', 'repetition']
# ['ambulation', 'frustration']
# ['repetition']
# ['repetition']
# ['frustration', 'repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['frustration', 'withdrawn']
# ['lost']
# ['vocal2', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['repetition', 'vocal1', 'withdrawn']
# ['vocal2', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['withdrawn']
# ['clothing', 'frustration', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['vocal1', 'vocal2']
# ['ambulation', 'communication', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'communication', 'frustration', 'touching', 'withdrawn']
# ['ambulation', 'clothing', 'frustration', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'vocal1', 'withdrawn']
# ['clothing', 'lost', 'vocal1']
# ['frustration', 'withdrawn']
# ['clothing', 'frustration', 'vocal1', 'withdrawn']
# ['clothing', 'frustration', 'touching']
# ['communication', 'touching']
# ['ambulation', 'clothing', 'frustration', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'clothing', 'frustration', 'repetition', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'clothing', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['vocal2']
# ['frustration', 'repetition', 'vocal1', 'vocal2']
# ['clothing', 'frustration', 'touching']
# ['vocal2']
# ['vocal1', 'withdrawn']
# ['vocal1']
# ['repetition', 'vocal1', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ...
# ['vocal2', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['withdrawn']
# ['clothing', 'frustration', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['vocal1', 'vocal2']
# ['ambulation', 'communication', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'communication', 'frustration', 'touching', 'withdrawn']
# ['ambulation', 'clothing', 'frustration', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'vocal1', 'withdrawn']
# ['clothing', 'lost', 'vocal1']
# ['frustration', 'withdrawn']
# ['clothing', 'frustration', 'vocal1', 'withdrawn']
# ['clothing', 'frustration', 'touching']
# ['communication', 'touching']
# ['ambulation', 'clothing', 'frustration', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'clothing', 'frustration', 'repetition', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'clothing', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['vocal2']
# ['frustration', 'repetition', 'vocal1', 'vocal2']
# ['clothing', 'frustration', 'touching']
# ['vocal2']
# ['vocal1', 'withdrawn']
# ['vocal1']
# ['repetition', 'vocal1', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['vocal1', 'withdrawn']
# ['lostrepetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['clothing']
# ['repetition']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication']
# ['communication', 'repetition']
# ['communication', 'repetition']
# ['repetition']
# ['communication', 'withdrawn']
# ['lost', 'repetition', 'touching', 'vocal1', 'withdrawn']
# ['repetition']
# ['oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['lost', 'repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['repetition']
# ['repetitionvocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['lost']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'frustration', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition']
# ['lostrepetition', 'vocal1']
# ['frustration', 'repetition', 'vocal1']
# ['repetition']
# ['lost', 'repetition', 'vocal1']
# ['lost', 'repetition', 'vocal1']
# ['repetition']
# ['frustration', 'repetition', 'vocal1']
# ['repetition']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['lostrepetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition']
# ['communication', 'repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication', 'lost']
# ['lost']
# ['lost']
# ['communication', 'lost']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'lost', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'vocal1']
# ['communication']
# ['communication']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'physical2', 'shadowing']
# ['repetition']
# ['vocal1']
# ['frustration']
# ['vocal1']
# ['withdrawn']
# ['repetition']
# ['frustration']
# ['withdrawn']
# ['communication', 'frustration']
# ['vocal1']
# ['ambulation', 'vocal1']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication']
# ['repetition']
# ['repetition']
# ['vocal2']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication', 'vocal1', 'vocal2']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['withdrawn']
# ['vocal1', 'withdrawn']
# ['withdrawn']
# ['withdrawn']
# ['vocal2', 'withdrawn']
# ['withdrawn']
# ['communication', 'vocal1', 'withdrawn']
# ['vocal10']
# ['vocal1', 'vocal2']
# ['repetition', 'vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal2']
# ['vocal1']
# ['vocal1', 'vocal2']
# ['repetition', 'vocal1', 'vocal2']
# ['withdrawn']
# ['repetition', 'vocal1', 'vocal2']
# ['vocal1']
# ['clothing', 'communication', 'vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['vocal1', 'vocal2']
# ['frustration', 'vocal1']
# ['vocal1', 'vocal2']
# ['communication', 'vocal1']
# ['vocal1', 'vocal2']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'vocal1', 'vocal2']
# ['repetition']
# ['repetition']
# ['communication']
# ['repetition']
# ['frustration']
# ['withdrawn']
# ['frustration', 'withdrawn']
# ['repetition']
# ['frustration', 'withdrawn']
# ['frustration', 'withdrawn']
# ['repetition']
# ['repetition']
# ['withdrawn']
# ['repetition']
# ['repetition']
# ['frustration']
# ['repetition']
# ['ambulation', 'frustration']
# ['communication']
# ['communication', 'repetition']
# ['repetition']
# ['repetition']
# ['frustration', 'withdrawn']
# ['lost']
# ['ambulation', 'frustration', 'withdrawn']
# ['frustration']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['frustration', 'withdrawn']
# ['repetition']
# ['repetition']
# ['repetition']
# ['frustration']
# ['repetition']
# ['lost']
# ['frustration', 'lost']
# ['frustration', 'lost', 'withdrawn']
# ['frustration', 'withdrawn']
# ['frustration', 'repetition']
# ['ambulation', 'frustration', 'repetition']
# ['ambulation', 'frustration']
# ['repetition']
# ['repetition']
# ['frustration', 'repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['frustration', 'withdrawn']
# ['lost']
# ['vocal2', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['repetition', 'vocal1', 'withdrawn']
# ['vocal2', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['withdrawn']
# ['clothing', 'frustration', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['vocal1', 'vocal2']
# ['ambulation', 'communication', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'communication', 'frustration', 'touching', 'withdrawn']
# ['ambulation', 'clothing', 'frustration', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'vocal1', 'withdrawn']
# ['clothing', 'lost', 'vocal1']
# ['frustration', 'withdrawn']
# ['clothing', 'frustration', 'vocal1', 'withdrawn']
# ['clothing', 'frustration', 'touching']
# ['communication', 'touching']
# ['ambulation', 'clothing', 'frustration', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'clothing', 'frustration', 'repetition', 'touching', 'vocal1', 'withdrawn']
# ['ambulation', 'clothing', 'frustration', 'touching', 'vocal1', 'withdrawn']
# ['vocal2']
# ['frustration', 'repetition', 'vocal1', 'vocal2']
# ['clothing', 'frustration', 'touching']
# ['vocal2']
# ['vocal1', 'withdrawn']
# ['vocal1']
# ['repetition', 'vocal1', 'withdrawn']
# ['vocal1', 'withdrawn']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['vocal1', 'withdrawn']
# ['lostrepetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1', 'withdrawn']
# ['repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['clothing']
# ['repetition']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication']
# ['communication', 'repetition']
# ['communication', 'repetition']
# ['repetition']
# ['communication', 'withdrawn']
# ['lost', 'repetition', 'touching', 'vocal1', 'withdrawn']
# ['repetition']
# ['oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['lost', 'repetition', 'vocal1']
# ['repetition', 'vocal1']
# ['repetition']
# ['repetitionvocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['lost']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'frustration', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition']
# ['lostrepetition', 'vocal1']
# ['frustration', 'repetition', 'vocal1']
# ['repetition']
# ['lost', 'repetition', 'vocal1']
# ['lost', 'repetition', 'vocal1']
# ['repetition']
# ['frustration', 'repetition', 'vocal1']
# ['repetition']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['lostrepetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition']
# ['communication', 'repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication', 'lost']
# ['lost']
# ['lost']
# ['communication', 'lost']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'lost', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'oralfixation', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'vocal1']
# ['communication']
# ['communication']
# ['repetition']
# ['communication', 'repetition', 'vocal1']
# ['communication']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'vocal1']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['communication', 'repetition', 'vocal1', 'withdrawn']
# ['repetition']
# ['communication']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'lost', 'repetition', 'vocal1']
# ['communication', 'repetition', 'vocal1']
# ['communication', 'physical2', 'shadowing']
# ['repetition']
# ['vocal1']
# ['frustration']
# ['vocal1']
# ['withdrawn']
# ['repetition']
# ['frustration']
# ['withdrawn']
# ['communication', 'frustration']
# ['vocal1']
# ['ambulation', 'vocal1']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication']
# ['repetition']
# ['repetition']
# ['vocal2']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['communication', 'vocal1', 'vocal2']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']
# ['repetition']

# %%
from nltk.tokenize import word_tokenize

# %%
words_list = []
for sentence in df.Observation:
    words_list.extend(nltk.word_tokenize(sentence))
freq_dist = nltk.FreqDist(words_list)
freq_dist.most_common(20)
# Out:
# [(';', 9728),
#  ('Repetition', 3216),
#  ('Vocal1', 2304),
#  ('Communication', 1504),
#  ('Withdrawn', 1280),
#  ('Frustration', 672),
#  ('Lost', 448),
#  ('Vocal2', 400),
#  ('Ambulation', 256),
#  ('Touching', 192),
#  (',', 176),
#  ('Clothing', 176),
#  ('OralFixation', 64),
#  ('Vocal1,0', 16),
#  ('Physical2', 16),
#  ('Shadowing', 16)]

# %%
temp = pd.DataFrame(freq_dist.most_common(30),  columns=['word', 'count'])
fig, ax = plt.subplots(figsize=(10, 6))
sns.barplot(x='word', y='count', 
            data=temp, ax=ax)
plt.title("Top words")
plt.xticks(rotation='vertical');

# %%
### Creating wordcloud
from wordcloud import WordCloud
import wordcloud
# creation of wordcloud
wcloud_fig = WordCloud( stopwords=set(wordcloud.STOPWORDS),
                      colormap='viridis', width=300, height=200).generate_from_frequencies(freq_dist)

# plotting the wordcloud
plt.figure(figsize=(10,7), frameon=True)

plt.imshow(wcloud_fig, interpolation  = 'bilinear')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

X = df.Observation
Y = df.Behaviour
le = LabelEncoder()
Y = le.fit_transform(Y)
Y = Y.reshape(-1, 1)

# %%
df['Behaviour'] = df['Behaviour'].map({"Normal" : 1,
                                     "Agitation" : 0})

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(df.Observation,df.Behaviour, test_size = 0.3, stratify = df.Behaviour
                                                 ,random_state = 42)

# %%
from keras.preprocessing.text import Tokenizer
num_words = 10000 # this means 15000 unique words can be taken 
tokenizer=Tokenizer(num_words,lower=True)
df_total = pd.concat([X_train, X_test], axis = 0)
tokenizer.fit_on_texts(df_total)

# %%
len(tokenizer.word_index)
# Out:
# 14

# %%
from keras_preprocessing.sequence import pad_sequences

X_train_ =tokenizer.texts_to_sequences(X_train)
X_train_pad=pad_sequences(X_train_,maxlen=171,padding='pre')
X_test_= tokenizer.texts_to_sequences(X_test)
X_test_pad = pad_sequences(X_test_, maxlen = 171, padding = 'pre')

# %%
print(X_train_pad.shape,X_test_pad.shape)
# Out:
# (3494, 171) (1498, 171)

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, LSTM, Embedding,Bidirectional,GRU,Flatten
import tensorflow
from tensorflow.compat.v1.keras.layers import CuDNNLSTM,CuDNNGRU
from tensorflow.keras.layers import Dropout

# %%
EMBEDDING_DIM = 100 # this means the embedding layer will create  a vector in 100 dimension
model = Sequential()
model.add(Embedding(input_dim = num_words,# the whole vocabulary size 
                          output_dim = EMBEDDING_DIM, # vector space dimension
                          input_length= X_train_pad.shape[1] # max_len of text sequence
                          ))
model.add(Dropout(0.4))
model.add(LSTM(100,return_sequences=True))
model.add(Dropout(0.4))
model.add(LSTM(200,return_sequences=True))
model.add(Dropout(0.4))
model.add(LSTM(100,return_sequences=False))
model.add(Dense(1, activation = 'sigmoid'))
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss = 'binary_crossentropy', optimizer = 'adam',metrics = 'accuracy')

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint


es = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 10)
mc = ModelCheckpoint('./model.h5', monitor = 'val_accuracy', mode = 'max', verbose = 1, save_best_only = True)

# %%
history_embedding = model.fit(X_train_pad,y_train, epochs = 15, batch_size = 120,validation_data=(X_test_pad, y_test),verbose = 1, callbacks= [es, mc]  )
# Out:
# Epoch 1/15
# 30/30 [==============================] - ETA: 0s - loss: 0.4743 - accuracy: 0.8300
# Epoch 1: val_accuracy improved from -inf to 0.83044, saving model to .\model.h5
# 30/30 [==============================] - 58s 2s/step - loss: 0.4743 - accuracy: 0.8300 - val_loss: 0.4478 - val_accuracy: 0.8304
# Epoch 2/15
# 30/30 [==============================] - ETA: 0s - loss: 0.4398 - accuracy: 0.8300
# Epoch 2: val_accuracy did not improve from 0.83044
# 30/30 [==============================] - 57s 2s/step - loss: 0.4398 - accuracy: 0.8300 - val_loss: 0.3936 - val_accuracy: 0.8304
# Epoch 3/15
# 30/30 [==============================] - ETA: 0s - loss: 0.3760 - accuracy: 0.8254
# Epoch 3: val_accuracy improved from 0.83044 to 0.84179, saving model to .\model.h5
# 30/30 [==============================] - 52s 2s/step - loss: 0.3760 - accuracy: 0.8254 - val_loss: 0.3550 - val_accuracy: 0.8418
# Epoch 4/15
# 30/30 [==============================] - ETA: 0s - loss: 0.3563 - accuracy: 0.8354
# Epoch 4: val_accuracy did not improve from 0.84179
# 30/30 [==============================] - 41s 1s/step - loss: 0.3563 - accuracy: 0.8354 - val_loss: 0.3418 - val_accuracy: 0.8258
# Epoch 5/15
# 30/30 [==============================] - ETA: 0s - loss: 0.3509 - accuracy: 0.8263
# Epoch 5: val_accuracy did not improve from 0.84179
# 30/30 [==============================] - 43s 1s/step - loss: 0.3509 - accuracy: 0.8263 - val_loss: 0.3364 - val_accuracy: 0.8385
# Epoch 6/15
# 30/30 [==============================] - ETA: 0s - loss: 0.3391 - accuracy: 0.8311
# Epoch 6: val_accuracy did not improve from 0.84179
# 30/30 [==============================] - 58s 2s/step - loss: 0.3391 - accuracy: 0.8311 - val_loss: 0.3246 - val_accuracy: 0.8258
# Epoch 7/15
# 30/30 [==============================] - ETA: 0s - loss: 0.3254 - accuracy: 0.8329
# Epoch 7: val_accuracy did not improve from 0.84179
# 30/30 [==============================] - 70s 2s/step - loss: 0.3254 - accuracy: 0.8329 - val_loss: 0.3198 - val_accuracy: 0.8378
# Epoch 8/15
# 30/30 [==============================] - ETA: 0s - loss: 0.3199 - accuracy: 0.8360
# Epoch 8: val_accuracy did not improve from 0.84179
# 30/30 [==============================] - 40s 1s/step - loss: 0.3199 - accuracy: 0.8360 - val_loss: 0.3090 - val_accuracy: 0.8418
# Epoch 9/15
# 30/30 [==============================] - ETA: 0s - loss: 0.3194 - accuracy: 0.8303
# Epoch 9: val_accuracy improved from 0.84179 to 0.84579, saving model to .\model.h5
# 30/30 [==============================] - 41s 1s/step - loss: 0.3194 - accuracy: 0.8303 - val_loss: 0.3051 - val_accuracy: 0.8458
# Epoch 10/15
# 30/30 [==============================] - ETA: 0s - loss: 0.3128 - accuracy: 0.8420
# Epoch 10: val_accuracy did not improve from 0.84579
# 30/30 [==============================] - 34s 1s/step - loss: 0.3128 - accuracy: 0.8420 - val_loss: 0.3114 - val_accuracy: 0.8291
# Epoch 11/15
# 30/30 [==============================] - ETA: 0s - loss: 0.3142 - accuracy: 0.8394
# Epoch 11: val_accuracy did not improve from 0.84579
# 30/30 [==============================] - 34s 1s/step - loss: 0.3142 - accuracy: 0.8394 - val_loss: 0.3162 - val_accuracy: 0.8338
# Epoch 12/15
# 30/30 [==============================] - ETA: 0s - loss: 0.3137 - accuracy: 0.8400
# Epoch 12: val_accuracy improved from 0.84579 to 0.84913, saving model to .\model.h5
# 30/30 [==============================] - 34s 1s/step - loss: 0.3137 - accuracy: 0.8400 - val_loss: 0.2994 - val_accuracy: 0.8491
# Epoch 13/15
# 30/30 [==============================] - ETA: 0s - loss: 0.3079 - accuracy: 0.8432
# Epoch 13: val_accuracy did not improve from 0.84913
# 30/30 [==============================] - 38s 1s/step - loss: 0.3079 - accuracy: 0.8432 - val_loss: 0.3073 - val_accuracy: 0.8291
# Epoch 14/15
# 30/30 [==============================] - ETA: 0s - loss: 0.3070 - accuracy: 0.8389
# Epoch 14: val_accuracy did not improve from 0.84913
# 30/30 [==============================] - 40s 1s/step - loss: 0.3070 - accuracy: 0.8389 - val_loss: 0.2967 - val_accuracy: 0.8378
# Epoch 15/15
# 30/30 [==============================] - ETA: 0s - loss: 0.3043 - accuracy: 0.8403
# Epoch 15: val_accuracy did not improve from 0.84913
# 30/30 [==============================] - 45s 2s/step - loss: 0.3043 - accuracy: 0.8403 - val_loss: 0.2911 - val_accuracy: 0.8451

# %%
pred = (model.predict(X_test_pad) > 0.5).astype("int32")
# Out:
# 47/47 [==============================] - 5s 103ms/step

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,pred)
# Out:
# 0.8451268357810414

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, pred, target_names = ['Agitation','Normal']))
# Out:
#               precision    recall  f1-score   support
#
#    Agitation       0.56      0.40      0.47       254
#       Normal       0.88      0.94      0.91      1244
#
#     accuracy                           0.85      1498
#    macro avg       0.72      0.67      0.69      1498
# weighted avg       0.83      0.85      0.83      1498

# %%
plt.plot(history_embedding.history['accuracy'],c='b',label='train accuracy')
plt.plot(history_embedding.history['val_accuracy'],c='r',label='validation accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
plt.plot(history_embedding.history['loss'],c='b',label='train loss')
plt.plot(history_embedding.history['val_loss'],c='r',label='validation loss')
plt.legend(loc='lower right')
plt.show()

# %%
df['Observation_Length'] = df['Observation'].apply(len)

# %%
Observation = df['Observation'].values
Behaviour = df['Behaviour'].values

# %%
VOCAB_SIZE = 1000
MAX_LEN = df['Observation_Length'].max()
EMBEDDING_VECTOR_SIZE = 50

# %%
encoded_message = [one_hot(obs, VOCAB_SIZE) for obs in Observation]
encoded_message
#  [576, 285, 336],
#  [576, 285, 336, 973],
#  [576, 285, 336],
#  [576, 285, 336],
#  [576, 285, 336],
#  [576, 285, 336, 973],
#  [285],
#  [576, 285, 336, 973],
#  [576, 285, 336],
#  [576, 285],
#  [576, 285, 336],
#  [576, 389, 285, 336],
#  [576, 336],
#  [576],
#  [576],
#  [285],
#  [576, 285, 336],
#  [576],
#  [576, 285, 336, 973],
#  [576, 336],
#  [576, 285, 336, 973],
#  [576, 336],
#  [576, 285, 336, 973],
#  [576, 285, 336, 973],
#  [285],
#  [576],
#  [576, 285, 336],
#  [576, 389, 285, 336],
#  [576, 285, 336],
#  [576, 251, 915],
#  [285],
#  [336],
#  [775],
#  [336],
#  [973],
#  [285],
#  [775],
#  [973],
#  [576, 775],
#  [336],
#  [980, 336],
#  [285],
#  [285],
#  [285],
#  [285],
#  [576],
#  [285],
#  [285],
#  [841],
#  [285],
#  [285],
#  [285],
#  [285],
#  [285],
#  [285],
#  [285],
#  [285],
#  [285],
#  [285],
#  [285],
#  [285],
#  [285],
#  [285],
#  [285],
#  [285],
#  [285],
#  [285],
#  [576, 336, 841],
#  [285],
#  [285],
#  [285],
#  [285],
#  [285],
#  [285],
#  [285],
#  [285],
#  [285],
#  [285],
#  [285],
#  [285],
#  [285],
#  [973],
#  [336, 973],
#  [973],
#  [973],
#  [841, 973],
#  [973],
#  [576, 336, 973],
#  [336, 838],
#  [336, 841],
#  [285, 336, 841],
#  [336, 841],
#  [841],
#  [336],
#  [336, 841],
#  [285, 336, 841],
#  [973],
#  [285, 336, 841],
#  [336],
#  [112, 576, 336, 841],
#  [336, 841],
#  [336, 841],
#  [336, 841],
#  [336, 841],
#  [336, 841],
#  [775, 336],
#  [336, 841],
#  [576, 336],
#  [336, 841],
#  [576, 285, 336],
#  [576, 336, 841],
#  [285],
#  [285],
#  [576],
#  [285],
#  [775],
#  [973],
#  [775, 973],
#  [285],
#  [775, 973],
#  [775, 973],
#  [285],
#  [285],
#  [973],
#  [285],
#  [285],
#  [775],
#  [285],
#  [980, 775],
#  [576],
#  [576, 285],
#  [285],
#  [285],
#  [775, 973],
#  [389],
#  [980, 775, 973],
#  [775],
#  [285],
#  [285],
#  [285],
#  [285],
#  [775, 973],
#  [285],
#  [285],
#  [285],
#  ...]

# %%
padded_message = pad_sequences(encoded_message, maxlen=MAX_LEN, padding='post')

# %%
X = padded_message
y = Behaviour

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True)

# %%
model1 = Sequential()
model1.add(Embedding(VOCAB_SIZE, EMBEDDING_VECTOR_SIZE, input_length = MAX_LEN, name='Embedding'))
model1.add(Bidirectional(LSTM(128, return_sequences=True)))
model1.add(Dropout(0.4))
model1.add(Bidirectional(GRU(64)))
model1.add(Flatten())
model1.add(Dropout(0.4))
model1.add(Dense(32, activation='relu'))
model1.add(Dense(1, activation='sigmoid'))

# %%
model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Embedding (Embedding)       (None, 75, 50)            50000
#
#  bidirectional (Bidirectiona  (None, 75, 256)          183296
#  l)
#
#  dropout_3 (Dropout)         (None, 75, 256)           0
#
#  bidirectional_1 (Bidirectio  (None, 128)              123648
#  nal)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 32)                4128
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 361,105
# Trainable params: 361,105
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
history = model1.fit(X_train, y_train, validation_data = (X_test,y_test), epochs=15, batch_size=100)
# Out:
# Epoch 1/15
# 35/35 [==============================] - 20s 410ms/step - loss: 0.4824 - accuracy: 0.8237 - val_loss: 0.4188 - val_accuracy: 0.8291
# Epoch 2/15
# 35/35 [==============================] - 15s 430ms/step - loss: 0.3737 - accuracy: 0.8214 - val_loss: 0.3267 - val_accuracy: 0.8291
# Epoch 3/15
# 35/35 [==============================] - 14s 394ms/step - loss: 0.3358 - accuracy: 0.8260 - val_loss: 0.3141 - val_accuracy: 0.8291
# Epoch 4/15
# 35/35 [==============================] - 13s 378ms/step - loss: 0.3288 - accuracy: 0.8271 - val_loss: 0.3236 - val_accuracy: 0.8291
# Epoch 5/15
# 35/35 [==============================] - 12s 353ms/step - loss: 0.3209 - accuracy: 0.8320 - val_loss: 0.3116 - val_accuracy: 0.8291
# Epoch 6/15
# 35/35 [==============================] - 14s 393ms/step - loss: 0.3147 - accuracy: 0.8291 - val_loss: 0.3111 - val_accuracy: 0.8291
# Epoch 7/15
# 35/35 [==============================] - 13s 375ms/step - loss: 0.3131 - accuracy: 0.8306 - val_loss: 0.3223 - val_accuracy: 0.8291
# Epoch 8/15
# 35/35 [==============================] - 13s 375ms/step - loss: 0.3143 - accuracy: 0.8271 - val_loss: 0.3113 - val_accuracy: 0.8291
# Epoch 9/15
# 35/35 [==============================] - 13s 366ms/step - loss: 0.3086 - accuracy: 0.8297 - val_loss: 0.3108 - val_accuracy: 0.8291
# Epoch 10/15
# 35/35 [==============================] - 13s 377ms/step - loss: 0.3085 - accuracy: 0.8317 - val_loss: 0.3051 - val_accuracy: 0.8311
# Epoch 11/15
# 35/35 [==============================] - 15s 419ms/step - loss: 0.3067 - accuracy: 0.8311 - val_loss: 0.3052 - val_accuracy: 0.8311
# Epoch 12/15
# 35/35 [==============================] - 13s 368ms/step - loss: 0.3041 - accuracy: 0.8334 - val_loss: 0.3049 - val_accuracy: 0.8371
# Epoch 13/15
# 35/35 [==============================] - 13s 366ms/step - loss: 0.3008 - accuracy: 0.8457 - val_loss: 0.2990 - val_accuracy: 0.8405
# Epoch 14/15
# 35/35 [==============================] - 13s 361ms/step - loss: 0.2948 - accuracy: 0.8480 - val_loss: 0.2942 - val_accuracy: 0.8485
# Epoch 15/15
# 35/35 [==============================] - 13s 377ms/step - loss: 0.2950 - accuracy: 0.8454 - val_loss: 0.2898 - val_accuracy: 0.8405

# %%
pred1 = (model1.predict(X_test) > 0.5).astype("int32")
# Out:
# 47/47 [==============================] - 4s 60ms/step

# %%
accuracy_score(y_test,pred1)
# Out:
# 0.8404539385847797

# %%
print(classification_report(y_test, pred1, target_names = ['Agitation','Normal']))
# Out:
#               precision    recall  f1-score   support
#
#    Agitation       0.67      0.13      0.22       256
#       Normal       0.85      0.99      0.91      1242
#
#     accuracy                           0.84      1498
#    macro avg       0.76      0.56      0.57      1498
# weighted avg       0.82      0.84      0.79      1498

# %%
plt.plot(history.history['accuracy'],c='b',label='train accuracy')
plt.plot(history.history['val_accuracy'],c='r',label='validation accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'],c='b',label='train loss')
plt.plot(history.history['val_loss'],c='r',label='validation loss')
plt.legend(loc='lower right')
plt.show()
